# %%
import os
import sys
# Root folder
sys.path.append("../..")

from PIL import Image

from apis.owlv2 import OWLViT, visualize_image

# %%
detector = OWLViT()

# %% [markdown]
# ## Test detection

# %%
import time
file_path = "./images/3.jpg"
image = Image.open(file_path)
# Example text queries
text_queries = [ 'handle']

time1 = time.time()

det_data = detector.detect_objects(
    image=image,
    text_queries=text_queries,
    bbox_score_top_k=20,
    bbox_conf_threshold=0.12
)

time2 = time.time()
print(f"Time taken: {time2 - time1:.2f}s")

for i, item in enumerate(det_data):
    print(f"--- Detection {i + 1} ---")
    print(f"Box Name: {item['box_name']}")
    print(f"Score: {item['score']}")
    print(f"Box Coordinates: {item['bbox']}")
# Out:
# Time taken: 0.76s
# --- Detection 1 ---
# Box Name: handle
# Score: 0.13016541302204132
# Box Coordinates: [0.4852024018764496, 0.47160378098487854, 0.5476759672164917, 0.49861618876457214]
# --- Detection 2 ---
# Box Name: handle
# Score: 0.20483370125293732
# Box Coordinates: [0.3777346909046173, 0.605108916759491, 0.39197632670402527, 0.6109244227409363]
# --- Detection 3 ---
# Box Name: handle
# Score: 0.17678366601467133
# Box Coordinates: [0.4110330045223236, 0.6360393166542053, 0.41729119420051575, 0.6745349764823914]
# --- Detection 4 ---
# Box Name: handle
# Score: 0.25469905138015747
# Box Coordinates: [0.7346746325492859, 0.6376951336860657, 0.7553508877754211, 0.649860143661499]
# --- Detection 5 ---
# Box Name: handle
# Score: 0.2519195079803467
# Box Coordinates: [0.7814264893531799, 0.6437481045722961, 0.8082564473152161, 0.6596375703811646]
# --- Detection 6 ---
# Box Name: handle
# Score: 0.2610611617565155
# Box Coordinates: [0.30107396841049194, 0.662153959274292, 0.33320263028144836, 0.6802065372467041]
# --- Detection 7 ---
# Box Name: handle
# Score: 0.24599559605121613
# Box Coordinates: [0.23487985134124756, 0.7039259076118469, 0.27169933915138245, 0.7277674078941345]
# --- Detection 8 ---
# Box Name: handle
# Score: 0.2181500643491745
# Box Coordinates: [0.7371386885643005, 0.7092634439468384, 0.7572565674781799, 0.7254946231842041]
# --- Detection 9 ---
# Box Name: handle
# Score: 0.2536690831184387
# Box Coordinates: [0.3018350899219513, 0.7539970874786377, 0.3273584246635437, 0.7750912308692932]
# --- Detection 10 ---
# Box Name: handle
# Score: 0.2968524992465973
# Box Coordinates: [0.8804017901420593, 0.7104485630989075, 0.912395179271698, 0.8205916285514832]
# --- Detection 11 ---
# Box Name: handle
# Score: 0.21895834803581238
# Box Coordinates: [0.7365111112594604, 0.799534022808075, 0.7577131986618042, 0.8206667304039001]
# --- Detection 12 ---
# Box Name: handle
# Score: 0.22107838094234467
# Box Coordinates: [0.22727784514427185, 0.8209258913993835, 0.2666010856628418, 0.8559926748275757]
# --- Detection 13 ---
# Box Name: handle
# Score: 0.22215348482131958
# Box Coordinates: [0.30299702286720276, 0.8672423958778381, 0.32655373215675354, 0.893467128276825]
# --- Detection 14 ---
# Box Name: handle
# Score: 0.1716950684785843
# Box Coordinates: [0.2372007966041565, 0.9658249616622925, 0.2682253122329712, 1.0003741979599]

# %%
visualize_image(image, bboxes=[obj["bbox"] for obj in det_data])
